# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/Geology-image-classification/blob/main/Model_for_epidote.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello Ate Grass!
#
# This notebook is still a work in progress. Di ko pa naeexplain lahat ng mga lines. Pero, we can run na this.
#
#
# Sa Google Drive natin na `Geology (Ate Grass)`, may excel file na CNN scores. Bale you will run **models 1,2,3,7,8,9**. Ako naman sa 4,5,6,10,11,12. Isang run lang ang pwede per google colab account. May limit din ang Google Colab  sa pag gamit ng GPU. Usually, I use my other google colab accounts pag ubos na hehe. Pwede mo rin siya irun simultaneously for different accounts. May tatlo akong email so may tatlo akong accounts.

# %% [markdown]
# # **1.Installing packages and connecting the google drive**

# %%
import torch
import torchvision
import torchvision.transforms as transforms

import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical
import os
from sklearn.model_selection import train_test_split

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd

import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # **2. Preparing the GDrive folder**
#
# First, go to Google Drive first. Nashare ko na noon yung folder na `Geology (Ate Grass)`. Nasa may "shared with me" siya sa google drive. Drag the whole folder sa "My Drive" para magcreate ng shortcut.
#
# Next, going back here sa Google Colab notebook, change the file_path in line 4 of the code below, depending on where the folder `3 classes (polarized)` is stored. An easy way to locate it is clicking the folder icon on the left side of this Colab Notebook. Select `drive`, then `MyDrive`. Hover the mouse on the target directory of the folder. Click the 3 dots, select `copy path`.
#
# Although I think yung nakalagay na file_path dito ay yun na mismo hehe. Palitan lang natin for the unpolarized  `3 classes (unpolarized)`

# %%
from google.colab import drive
drive.mount("/content/drive")
# !ls drive/My\ Drive
file_path = "/content/drive/MyDrive/Geology (Ate Grass)/2 classes (XPL)"
# Out:
# Mounted at /content/drive
# '107.1 syllabus 1SAY1920 FINAL.gdoc'
# '1C-01 Narag et al (1).pdf'
# '1C-01 Narag et al.pdf'
# '1FA971504AC646559D05A8ED6341AFB3[1025340].png'
# '1H-04 Narag et al.pdf'
#  20220802_182749.heic
#  20220802_182831.heic
#  20220802_183259.heic
#  20220803_125819.heic
#  20220803_125842.heic
#  20220803_144229.heic
#  20220803_144422.heic
#  20220803_160724.heic
#  20220803_160751.heic
#  20220803_165240.heic
#  20220803_165318.heic
#  20220803_174701.heic
#  20220803_174706.heic
#  20220804_175217.heic
#  20220804_175443.heic
#  20220804_175616.heic
#  20220804_181917.heic
#  20220804_182007.heic
#  20220804_182117.heic
#  2S22-23_LE3-Regular-Set-A-FINAL-KEY.pdf
# '3 classes (polarized)CM_alexnet.png'
# '3 classes (polarized)CM_vgg.png'
# 'A4_Physics 71 TWHFU-3_gradesheet (1).pdf'
# 'A4_Physics 71 TWHFU-3_officialgrades (1).pdf'
# 'A4_Physics 71 TWHFU-3_officialgrades.gdoc'
# 'Abstract - NARAG, Mark Jeremy.pdf'
# 'Annex 1 (copy of Journal).pdf'
# 'Annex 2 (Proof of employments).pdf'
# 'App Physics 181 THY-FX-2_studentcontactlist.xlsx'
#  Architectural_designs
# 'Arki abstract.pdf'
# 'Arki full paper.pdf'
# '[ART] Example of Objectives - Activities - Exp Output OPTIKAL WBS version 2.gsheet'
#  autoencoder_fine_tuned_6
# 'autoencoder_fine_tuned_6 (1)'
#  autoencoder_fine_tuned_6_b
# 'Baumgartner screenshots'
# 'Binarizing architectural drawings'
#  classification_report_nonTL.xlsx
#  classification_report.xlsx
#  Classroom
# 'Colab Notebooks'
# 'Color Difference Specification 2016.pptx'
#  confusion_matrix_nonTL.png
#  confusion_matrix_nonTL.xlsx
#  CS284
#  CS_NIP_201819_S2_BS_AppliedPhysics_Narag_Mark_Jeremy.pdf
#  D54dUVpU8AIZzoD.jpeg
#  Data.tex
# 'Dormitory Stay Request MNarag.docx.pdf'
# '[DRAFT-ART] UP Intelligent Systems Center Research Grant Application - Preview.docx'
#  DrzPc0sUwAAyQHi.jpeg
#  DvO96koV4AAD6PP.jpeg
# 'DvO976tVAAEQ9ym (1).jpeg'
#  DvO976tVAAEQ9ym.jpeg
# 'Employment Survey.gdoc'
#  Fast-Dreambooth
# 'FBC-2_Banez (1).pdf'
#  FBC-2_Banez.pdf
#  FdUaD2nUcAAki1b.jpeg
# 'Figure 1.png'
# 'Figure 2.png'
# 'fingerprint (1).pb'
# 'fingerprint (2).pb'
# 'fingerprint (3).pb'
# 'fingerprint (4).pb'
# 'fingerprint (5).pb'
#  fingerprint.pb
# 'Form5a and Grades.zip'
#  Fringes.zip
#  FSR_120201_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120202_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120212_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120221_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
# 'Geology (Ate Grass)'
# 'Geology (Ate Grass) (1)'
# 'Getting started.pdf'
#  IMG_4258.HEIC
#  IMG_4259.HEIC
#  IMG_4260.HEIC
#  IMG_4261.HEIC
#  IMG_4262.HEIC
#  IMG_4263.HEIC
#  IMG_4288.HEIC
#  IMG_5634.JPG
#  IMG_6572.jpeg
#  IMG_6578.jpeg
# 'IMG_6587 (1).jpeg'
#  IMG_6587.jpeg
#  IPA-Form4.1-2021Rev072021-1.pdf
#  IPA-Form4.2-2021Rev072021.docx
#  IPA-Form4.3-2021Rev072021.pdf
# 'item sample.tex'
# 'item template.tex'
# 'Jas Jem utang.gsheet'
#  Jem_face
# 'JFR Reduced Fees for 1st Sem AY 20-21.zip'
# 'Lecture 22 - Torque.pptx'
# 'Lecture 23 - Dynamics of Rotation.pptx'
# 'Lecture 24 - Angular Momentum.pptx'
# 'Lecture 25 - Equilibrium and Center of Gravity.pptx'
# 'Lecture 26 - Density and Pressure in a Fluid.pptx'
# 'Lecture 27 - Buoyancy.pptx'
# 'LRM_20220804_195432 (1).dng'
#  LRM_20220804_195432.dng
#  LRM_20220804_195500.dng
#  LRM_20220804_195546.dng
#  LRM_20220805_113837.dng
#  LRM_20220805_142837.dng
#  LRM_20220805_143054.dng
#  LRM_20220805_143817.dng
# 'MALIPOL_CHAE ANN.pdf'
#  Metric_100dpi.csv
#  Metric_500.csv
# 'NARAG_MARKJEREMY (1).BC.pdf'
#  NARAG_MARKJEREMY.BC.pdf
#  NARAG_MARKJEREMY.CC.png
#  NARAG_MARKJEREMY.dcog.pdf
#  NARAG_MARKJEREMY.DC.pdf
#  NARAG_MARKJEREMY.FL.pdf
#  NARAG_MARKJEREMY.Form1.1.pdf
#  NARAG_MARKJEREMY.POS.pdf
#  NARAG_MARKJEREMY.SD.pdf
#  NARAG_MARKJEREMY.TCGTOR.pdf
# '[NARAG] Physics 242 Final Report.pdf'
# '[NARAG] Physics 242 PS 1.pdf'
# '[NARAG] Physics 242 PS 2.pdf'
# 'Narag SPP Cert.pdf'
#  NARAG_Travel-Report-Form-2019.pdf
# 'NIP COVID-19 Case Report Form.gform'
# 'NIP COVID-19 Case Report Form (Responses).gsheet'
# 'NIP COVID19 Report.gsheet'
# 'NIP Year End Party 2022'
#  NRAG_MARKJEREMY.OTRTCG.pdf
# 'Optics in Art and Art Analysis (1).pptx'
# 'Optics in Art and Art Analysis.pptx'
# 'OUR CErtificate.gdoc'
# 'OUR CErtificate.pdf'
# 'output v1_100dpi.png'
# 'output v2_100dpi.png'
# 'output v3_100dpi.png'
# 'output v3_500.png'
# 'output v4_100dpi.png'
# 'output v5_100dpi.png'
# 'output v6_100dpi.png'
# 'OVCRD IPA Reference Slip (2021-0929-1691-5873).pdf'
# 'PA-08 Narag et al.pdf'
#  PA-08.pdf
# 'Parallel Presentation.gslides'
# 'PEER EVALUTION - Physics 72.1 HBC-1 .gform'
# 'PEER EVALUTION - Physics 72.1 TDE-1 .gform'
# 'PEER EVALUTION - Physics 72.1 WDE-1 .gform'
# 'PhD Candidacy Slides.pdf'
# 'PhD Candidacy Slides.pptx'
# 'Physics 107.1 Drive'
# 'Physics 107.1 MBCD-2_studentcontactlist.xlsx'
#  Physics305_plasma
# 'Physics 71.1 WIJ FIJ and 72.1 TBC.gsheet'
#  Physics_71_Syllabus.zip
# 'Physics_71_Syllabus.zip (Unzipped Files)'
# '[Physics 71 V-2] Attendance.gsheet'
# 'Physics 72.1 2nd Sem AY 2019-2020.gsheet'
# 'Rene Jem utang.gsheet'
# 'Research files'
# 'Sablay picture.jpeg'
# 'saved_model (1).pb'
# 'saved_model (2).pb'
# 'saved_model (3).pb'
# 'saved_model (4).pb'
# 'saved_model (5).pb'
#  saved_model.pb
# 'Screenshot 2023-02-12 at 12.13.51 (1).png'
# 'Screenshot 2023-02-12 at 12.13.51.png'
# 'Screenshot 2023-06-29 at 19.20.04.png'
# 'Screenshot 2023-06-29 at 19.26.09.png'
#  sd
#  Smokers.mp4
# 'SORRY SIR HUHU.gdoc'
# 'SORRY SIR HUHU.pdf'
# 'SPP-2023-1H-04 (1).pptx'
#  SPP-2023-1H-04.pptx
#  SPP_2023-Contributed-26.pdf
# 'SPP-2023-PB-05  .pdf'
#  SPP_Appearance-45.pdf
# 'SPP Cert of Appearance NARAG (1).pdf'
# 'SPP Cert of Appearance NARAG (2).pdf'
# 'SPP Cert of Appearance NARAG.pdf'
# 'Testing on DIV2K dataset.pdf'
# '[THY-FX] Physics 181 LE1 Submissions 2nd Sem AY 2020-21'
#  Travel-Report-Form-2019.pdf
# 'Undergraduate Research'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
# '[Updated] Physics 71 THQ-FQ-1_studentcontactlist (1).xlsx'
# '[Updated] Physics 71 THQ-FQ-1_studentcontactlist.xlsx'
# 'variables (1).data-00000-of-00001'
# 'variables (2).data-00000-of-00001'
# 'variables (3).data-00000-of-00001'
# 'variables (4).data-00000-of-00001'
# 'variables (5).data-00000-of-00001'
#  variables.data-00000-of-00001
# 'Waiver for more than 18 units [2nd sem AY 20-21].gdoc'

# %% [markdown]
# # **3.Preparing the training and validation dataset**
# ### make sure to change the `img_size` to the correct image size of the model:
# *   For ALEXNET, it is 227 by 227
# *   For VGG16, it is 224 by 224
# *   For RESNET, it is 224 by 224

# %%
img_size = 224

# Function to resize images to img_size
def resize_image(image_path):
    img = load_img(image_path, target_size=(img_size, img_size))
    img_array = img_to_array(img) / 255.0
    return img_array


def rot_and_flip(img):
  x = np.rot90(img, k=-1) #90
  train_images.append(x)
  train_labels.append(class_name)
  #train_images.append(np.fliplr(x))
  #train_labels.append(class_name)
  return x

# Load and preprocess training data
train_images = []
train_labels = []

train_dir = file_path + '/Training/'
class_labels = ["epidote",  "no epidote"]

for class_name in class_labels:
    class_dir = os.path.join(train_dir, class_name)
    for image_name in os.listdir(class_dir):
        image_path = os.path.join(class_dir, image_name)
        x = resize_image(image_path)
        train_images.append(x)
        train_labels.append(class_name)
        #rotate and flip if we want to augment. Pero wag muna
        #x = rot_and_flip(x) #90
        #x = rot_and_flip(x) #180
        #x = rot_and_flip(x) #270


# Convert lists to numpy arrays
train_images = np.array(train_images)
train_labels = np.array(train_labels)

print('shape of total dataset', np.shape(train_images))
print('shape of total dataset label', np.shape(train_labels))

# Encode class names into numerical labels
label_encoder = LabelEncoder()
label_encoder.fit(class_labels)
train_labels_encoded = label_encoder.fit_transform(train_labels)

# Convert numerical labels to one-hot encoded vectors
train_labels = to_categorical(train_labels_encoded, num_classes=len(class_labels))


#train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2, stratify=train_labels, random_state=42)

print('shape of dataset for training', np.shape(train_images))
print('shape of dataset label for training', np.shape(train_labels))
print('shape of dataset for validation', np.shape(val_images))
print('shape of dataset label for validation', np.shape(val_labels))
# Out:
# shape of total dataset (1400, 224, 224, 3)
# shape of total dataset label (1400,)
# shape of dataset for training (1120, 224, 224, 3)
# shape of dataset label for training (1120, 2)
# shape of dataset for validation (280, 224, 224, 3)
# shape of dataset label for validation (280, 2)

# %% [markdown]
#  Visualize:

# %%
import matplotlib.pyplot as plt

def display_images(images, labels, class_names, num_images=20):
    plt.figure(figsize=(15, 6))
    for i in range(num_images):
        plt.subplot(4, 5, i+1)
        plt.imshow(images[i])
        label_index = np.argmax(labels[i])
        plt.title(class_names[label_index])
        plt.axis('off')
    plt.show()

# Decode one-hot encoded labels back to class names
class_names = label_encoder.classes_

# Display the first 20 training images
display_images(train_images[:20], train_labels[:20], class_names)

# %% [markdown]
# # **4. Training the model**
#
# We will train three (3) different models. We will run them separately.

# %% [markdown]
# ### **RUN THIS FOR ALEXNET**
# There is no built-in model for alexnet so we have to create it from scratch

# %%
#AlexNet architecture from scratch
alex_model = Sequential([
    Conv2D(96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(227, 227, 3)),
    MaxPooling2D(pool_size=(3,3), strides=(2,2)),
    Conv2D(256, kernel_size=(5,5), activation='relu'),
    MaxPooling2D(pool_size=(3,3), strides=(2,2)),
    Conv2D(384, kernel_size=(3,3), activation='relu'),
    Conv2D(384, kernel_size=(3,3), activation='relu'),
    Conv2D(256, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(3,3), strides=(2,2)),
    Flatten(),
    Dense(4096, activation='relu'),
    Dropout(0.5),
    Dense(4096, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')
])


from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.0001)

alex_model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
# Train  model
alex_model.fit(train_images, train_labels, epochs=100, batch_size=8, validation_data=(val_images, val_labels))
alex_model.save(file_path + "/Models/alex_model")

# %% [markdown]
# ### **RUN THIS FOR VGG16**
# There is already a built-in model for vgg16 so we don't need to create it from scratch

# %%
# Load VGG16 mode:
vgg_base = tf.keras.applications.VGG16(include_top=False, input_shape=(224, 224, 3))
#Add "weights='imagenet'" if we want pretrained weights

# Freeze the pre-trained layers
for layer in vgg_base.layers:
    layer.trainable = True

# Add custom classifier layers on top of the pre-trained layers
x = Flatten()(vgg_base.output)
x = Dense(4096, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(4096, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(2, activation='softmax')(x) #because we have 3 classes

# Create the full model
vgg_model = Model(inputs=vgg_base.input, outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.00001)
vgg_model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
vgg_model.fit(train_images, train_labels, epochs=100, batch_size=8, validation_data=(val_images, val_labels))
vgg_model.save(file_path + "/Models/vgg_model")

# %% [markdown]
# ### **RUN THIS FOR RESNET**

# %%
resnet_base = tf.keras.applications.ResNet50(include_top=False, input_shape=(224, 224, 3))

# Freeze the pre-trained layers
for layer in resnet_base.layers:
    layer.trainable = True

# Add custom classifier layers on top of the pre-trained layers
x = Flatten()(resnet_base.output)
x = Dense(4096, activation='relu')(x)
x = Dense(4096, activation='relu')(x)
output = Dense(2, activation='softmax')(x)

# Create the full model
resnet_model = Model(inputs=resnet_base.input, outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.00001)
resnet_model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
resnet_model.fit(train_images, train_labels, epochs=100, batch_size=8, validation_data=(val_images, val_labels))
resnet_model.save(file_path + "/Models/resnet_model")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Epoch 1/100
# 140/140 [==============================] - 75s 238ms/step - loss: 0.5213 - accuracy: 0.8143 - val_loss: 0.9279 - val_accuracy: 0.5000
# Epoch 2/100
# 140/140 [==============================] - 30s 214ms/step - loss: 0.0999 - accuracy: 0.9714 - val_loss: 0.6770 - val_accuracy: 0.5536
# Epoch 3/100
# 140/140 [==============================] - 30s 214ms/step - loss: 0.0548 - accuracy: 0.9839 - val_loss: 2.4986 - val_accuracy: 0.5000
# Epoch 4/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0201 - accuracy: 0.9929 - val_loss: 1.2401 - val_accuracy: 0.5143
# Epoch 5/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0265 - accuracy: 0.9893 - val_loss: 2.7518 - val_accuracy: 0.5214
# Epoch 6/100
# 140/140 [==============================] - 30s 214ms/step - loss: 0.0199 - accuracy: 0.9937 - val_loss: 1.9176 - val_accuracy: 0.5786
# Epoch 7/100
# 140/140 [==============================] - 30s 214ms/step - loss: 0.0878 - accuracy: 0.9714 - val_loss: 0.6254 - val_accuracy: 0.7857
# Epoch 8/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0381 - accuracy: 0.9902 - val_loss: 1.7141 - val_accuracy: 0.7000
# Epoch 9/100
# 140/140 [==============================] - 31s 223ms/step - loss: 0.0415 - accuracy: 0.9920 - val_loss: 1.2053 - val_accuracy: 0.8321
# Epoch 10/100
# 140/140 [==============================] - 31s 223ms/step - loss: 0.0272 - accuracy: 0.9902 - val_loss: 0.5559 - val_accuracy: 0.9214
# Epoch 11/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0585 - accuracy: 0.9866 - val_loss: 0.4888 - val_accuracy: 0.9357
# Epoch 12/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0102 - accuracy: 0.9955 - val_loss: 0.4666 - val_accuracy: 0.9357
# Epoch 13/100
# 140/140 [==============================] - 30s 214ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.7638 - val_accuracy: 0.8857
# Epoch 14/100
# 140/140 [==============================] - 30s 214ms/step - loss: 0.0095 - accuracy: 0.9982 - val_loss: 0.6140 - val_accuracy: 0.9143
# Epoch 15/100
# 140/140 [==============================] - 31s 223ms/step - loss: 0.0034 - accuracy: 0.9982 - val_loss: 0.5336 - val_accuracy: 0.9214
# Epoch 16/100
# 140/140 [==============================] - 30s 214ms/step - loss: 0.0071 - accuracy: 0.9964 - val_loss: 0.7469 - val_accuracy: 0.9036
# Epoch 17/100
# 140/140 [==============================] - 30s 214ms/step - loss: 6.5510e-04 - accuracy: 1.0000 - val_loss: 0.8611 - val_accuracy: 0.8964
# Epoch 18/100
# 140/140 [==============================] - 30s 214ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.7495 - val_accuracy: 0.9143
# Epoch 19/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0262 - accuracy: 0.9964 - val_loss: 0.7877 - val_accuracy: 0.9179
# Epoch 20/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.1019 - accuracy: 0.9750 - val_loss: 0.5704 - val_accuracy: 0.9286
# Epoch 21/100
# 140/140 [==============================] - 30s 214ms/step - loss: 0.0238 - accuracy: 0.9937 - val_loss: 0.9902 - val_accuracy: 0.8857
# Epoch 22/100
# 140/140 [==============================] - 31s 223ms/step - loss: 0.0518 - accuracy: 0.9866 - val_loss: 0.9359 - val_accuracy: 0.9143
# Epoch 23/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0244 - accuracy: 0.9937 - val_loss: 1.0394 - val_accuracy: 0.9036
# Epoch 24/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0255 - accuracy: 0.9991 - val_loss: 0.7418 - val_accuracy: 0.9286
# Epoch 25/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0086 - accuracy: 0.9946 - val_loss: 0.5233 - val_accuracy: 0.9357
# Epoch 26/100
# 140/140 [==============================] - 30s 215ms/step - loss: 7.1647e-04 - accuracy: 1.0000 - val_loss: 0.6741 - val_accuracy: 0.9286
# Epoch 27/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0226 - accuracy: 0.9920 - val_loss: 1.1207 - val_accuracy: 0.9000
# Epoch 28/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0130 - accuracy: 0.9964 - val_loss: 0.8716 - val_accuracy: 0.9179
# Epoch 29/100
# 140/140 [==============================] - 30s 216ms/step - loss: 0.0241 - accuracy: 0.9920 - val_loss: 1.0161 - val_accuracy: 0.9214
# Epoch 30/100
# 140/140 [==============================] - 30s 214ms/step - loss: 0.0531 - accuracy: 0.9857 - val_loss: 0.7984 - val_accuracy: 0.9250
# Epoch 31/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0624 - accuracy: 0.9920 - val_loss: 0.9644 - val_accuracy: 0.9143
# Epoch 32/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0251 - accuracy: 0.9937 - val_loss: 0.6067 - val_accuracy: 0.9286
# Epoch 33/100
# 140/140 [==============================] - 30s 216ms/step - loss: 0.0099 - accuracy: 0.9973 - val_loss: 0.7659 - val_accuracy: 0.9357
# Epoch 34/100
# 140/140 [==============================] - 30s 215ms/step - loss: 2.1046e-04 - accuracy: 1.0000 - val_loss: 0.8727 - val_accuracy: 0.9286
# Epoch 35/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 1.0398 - val_accuracy: 0.9214
# Epoch 36/100
# 140/140 [==============================] - 30s 217ms/step - loss: 0.0133 - accuracy: 0.9973 - val_loss: 1.0754 - val_accuracy: 0.9214
# Epoch 37/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0276 - accuracy: 0.9929 - val_loss: 1.3694 - val_accuracy: 0.9143
# Epoch 38/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0361 - accuracy: 0.9946 - val_loss: 0.4822 - val_accuracy: 0.9500
# Epoch 39/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.6741 - val_accuracy: 0.9393
# Epoch 40/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0548 - accuracy: 0.9955 - val_loss: 0.4969 - val_accuracy: 0.9464
# Epoch 41/100
# 140/140 [==============================] - 31s 224ms/step - loss: 7.9805e-04 - accuracy: 1.0000 - val_loss: 0.7244 - val_accuracy: 0.9214
# Epoch 42/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0018 - accuracy: 0.9991 - val_loss: 0.4663 - val_accuracy: 0.9429
# Epoch 43/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0011 - accuracy: 0.9991 - val_loss: 0.6322 - val_accuracy: 0.9357
# Epoch 44/100
# 140/140 [==============================] - 30s 215ms/step - loss: 7.9296e-04 - accuracy: 1.0000 - val_loss: 0.7622 - val_accuracy: 0.9214
# Epoch 45/100
# 140/140 [==============================] - 31s 224ms/step - loss: 7.1672e-05 - accuracy: 1.0000 - val_loss: 0.6820 - val_accuracy: 0.9286
# Epoch 46/100
# 140/140 [==============================] - 30s 215ms/step - loss: 2.3001e-04 - accuracy: 1.0000 - val_loss: 0.7773 - val_accuracy: 0.9214
# Epoch 47/100
# 140/140 [==============================] - 30s 215ms/step - loss: 1.9331e-05 - accuracy: 1.0000 - val_loss: 0.7227 - val_accuracy: 0.9250
# Epoch 48/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0015 - accuracy: 0.9982 - val_loss: 0.9891 - val_accuracy: 0.9286
# Epoch 49/100
# 140/140 [==============================] - 30s 215ms/step - loss: 4.4478e-04 - accuracy: 1.0000 - val_loss: 0.8053 - val_accuracy: 0.9393
# Epoch 50/100
# 140/140 [==============================] - 30s 215ms/step - loss: 8.4367e-06 - accuracy: 1.0000 - val_loss: 0.8315 - val_accuracy: 0.9357
# Epoch 51/100
# 140/140 [==============================] - 30s 215ms/step - loss: 4.4522e-05 - accuracy: 1.0000 - val_loss: 0.7301 - val_accuracy: 0.9429
# Epoch 52/100
# 140/140 [==============================] - 31s 225ms/step - loss: 4.2003e-05 - accuracy: 1.0000 - val_loss: 0.7453 - val_accuracy: 0.9429
# Epoch 53/100
# 140/140 [==============================] - 31s 224ms/step - loss: 5.3891e-04 - accuracy: 1.0000 - val_loss: 0.5866 - val_accuracy: 0.9429
# Epoch 54/100
# 140/140 [==============================] - 30s 215ms/step - loss: 3.8559e-05 - accuracy: 1.0000 - val_loss: 0.6848 - val_accuracy: 0.9464
# Epoch 55/100
# 140/140 [==============================] - 30s 215ms/step - loss: 1.5778e-04 - accuracy: 1.0000 - val_loss: 0.5187 - val_accuracy: 0.9536
# Epoch 56/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0042 - accuracy: 0.9982 - val_loss: 0.8571 - val_accuracy: 0.9250
# Epoch 57/100
# 140/140 [==============================] - 31s 225ms/step - loss: 0.0489 - accuracy: 0.9982 - val_loss: 0.8249 - val_accuracy: 0.9357
# Epoch 58/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0948 - accuracy: 0.9839 - val_loss: 1.8892 - val_accuracy: 0.9036
# Epoch 59/100
# 140/140 [==============================] - 30s 216ms/step - loss: 0.0698 - accuracy: 0.9920 - val_loss: 0.6542 - val_accuracy: 0.9250
# Epoch 60/100
# 140/140 [==============================] - 30s 216ms/step - loss: 0.0375 - accuracy: 0.9937 - val_loss: 0.8153 - val_accuracy: 0.9179
# Epoch 61/100
# 140/140 [==============================] - 30s 215ms/step - loss: 6.6295e-04 - accuracy: 1.0000 - val_loss: 0.8401 - val_accuracy: 0.9107
# Epoch 62/100
# 140/140 [==============================] - 30s 215ms/step - loss: 1.8659e-04 - accuracy: 1.0000 - val_loss: 0.6901 - val_accuracy: 0.9286
# Epoch 63/100
# 140/140 [==============================] - 32s 225ms/step - loss: 0.0019 - accuracy: 0.9982 - val_loss: 0.6029 - val_accuracy: 0.9393
# Epoch 64/100
# 140/140 [==============================] - 30s 216ms/step - loss: 1.9508e-04 - accuracy: 1.0000 - val_loss: 0.5408 - val_accuracy: 0.9429
# Epoch 65/100
# 140/140 [==============================] - 31s 225ms/step - loss: 2.8288e-04 - accuracy: 1.0000 - val_loss: 0.8772 - val_accuracy: 0.9143
# Epoch 66/100
# 140/140 [==============================] - 31s 225ms/step - loss: 9.9580e-05 - accuracy: 1.0000 - val_loss: 0.7306 - val_accuracy: 0.9321
# Epoch 67/100
# 140/140 [==============================] - 30s 216ms/step - loss: 5.9153e-05 - accuracy: 1.0000 - val_loss: 0.6827 - val_accuracy: 0.9357
# Epoch 68/100
# 140/140 [==============================] - 30s 217ms/step - loss: 2.4160e-05 - accuracy: 1.0000 - val_loss: 0.6996 - val_accuracy: 0.9321
# Epoch 69/100
# 140/140 [==============================] - 30s 216ms/step - loss: 3.4386e-06 - accuracy: 1.0000 - val_loss: 0.7038 - val_accuracy: 0.9321
# Epoch 70/100
# 140/140 [==============================] - 30s 217ms/step - loss: 5.2890e-07 - accuracy: 1.0000 - val_loss: 0.6954 - val_accuracy: 0.9321
# Epoch 71/100
# 140/140 [==============================] - 31s 225ms/step - loss: 4.1891e-06 - accuracy: 1.0000 - val_loss: 0.7082 - val_accuracy: 0.9321
# Epoch 72/100
# 140/140 [==============================] - 30s 216ms/step - loss: 1.2653e-06 - accuracy: 1.0000 - val_loss: 0.7062 - val_accuracy: 0.9321
# Epoch 73/100
# 140/140 [==============================] - 31s 225ms/step - loss: 1.8049e-05 - accuracy: 1.0000 - val_loss: 0.6671 - val_accuracy: 0.9357
# Epoch 74/100
# 140/140 [==============================] - 32s 225ms/step - loss: 1.5759e-05 - accuracy: 1.0000 - val_loss: 0.6961 - val_accuracy: 0.9357
# Epoch 75/100
# 140/140 [==============================] - 30s 216ms/step - loss: 0.0019 - accuracy: 0.9991 - val_loss: 0.7913 - val_accuracy: 0.9286
# Epoch 76/100
# 140/140 [==============================] - 31s 225ms/step - loss: 3.2137e-05 - accuracy: 1.0000 - val_loss: 0.7042 - val_accuracy: 0.9321
# Epoch 77/100
# 140/140 [==============================] - 30s 216ms/step - loss: 1.1867e-05 - accuracy: 1.0000 - val_loss: 0.6863 - val_accuracy: 0.9393
# Epoch 78/100
# 140/140 [==============================] - 30s 215ms/step - loss: 5.9984e-05 - accuracy: 1.0000 - val_loss: 1.0188 - val_accuracy: 0.9214
# Epoch 79/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0323 - accuracy: 0.9902 - val_loss: 1.6188 - val_accuracy: 0.9071
# Epoch 80/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0571 - accuracy: 0.9920 - val_loss: 0.9393 - val_accuracy: 0.9357
# Epoch 81/100
# 140/140 [==============================] - 30s 216ms/step - loss: 0.0667 - accuracy: 0.9902 - val_loss: 0.9248 - val_accuracy: 0.9429
# Epoch 82/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0771 - accuracy: 0.9937 - val_loss: 0.9036 - val_accuracy: 0.9393
# Epoch 83/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0017 - accuracy: 0.9991 - val_loss: 0.9588 - val_accuracy: 0.9393
# Epoch 84/100
# 140/140 [==============================] - 32s 226ms/step - loss: 0.0552 - accuracy: 0.9982 - val_loss: 0.6185 - val_accuracy: 0.9464
# Epoch 85/100
# 140/140 [==============================] - 31s 224ms/step - loss: 1.4152e-04 - accuracy: 1.0000 - val_loss: 0.6706 - val_accuracy: 0.9393
# Epoch 86/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0152 - accuracy: 0.9964 - val_loss: 0.7091 - val_accuracy: 0.9429
# Epoch 87/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0071 - accuracy: 0.9982 - val_loss: 0.9329 - val_accuracy: 0.9286
# Epoch 88/100
# 140/140 [==============================] - 30s 216ms/step - loss: 0.0327 - accuracy: 0.9955 - val_loss: 0.7666 - val_accuracy: 0.9464
# Epoch 89/100
# 140/140 [==============================] - 30s 216ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.7665 - val_accuracy: 0.9464
# Epoch 90/100
# 140/140 [==============================] - 30s 215ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 1.5929 - val_accuracy: 0.8964
# Epoch 91/100
# 140/140 [==============================] - 30s 216ms/step - loss: 0.0457 - accuracy: 0.9955 - val_loss: 1.3385 - val_accuracy: 0.9143
# Epoch 92/100
# 140/140 [==============================] - 30s 216ms/step - loss: 0.0192 - accuracy: 0.9964 - val_loss: 1.4327 - val_accuracy: 0.8964
# Epoch 93/100
# 140/140 [==============================] - 30s 216ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.8232 - val_accuracy: 0.9286
# Epoch 94/100
# 140/140 [==============================] - 31s 224ms/step - loss: 2.7295e-05 - accuracy: 1.0000 - val_loss: 0.8450 - val_accuracy: 0.9286
# Epoch 95/100
# 140/140 [==============================] - 30s 216ms/step - loss: 1.3725e-05 - accuracy: 1.0000 - val_loss: 0.8594 - val_accuracy: 0.9286
# Epoch 96/100
# 140/140 [==============================] - 31s 224ms/step - loss: 3.5122e-06 - accuracy: 1.0000 - val_loss: 0.8624 - val_accuracy: 0.9286
# Epoch 97/100
# 140/140 [==============================] - 31s 225ms/step - loss: 3.7939e-06 - accuracy: 1.0000 - val_loss: 0.8744 - val_accuracy: 0.9286
# Epoch 98/100
# 140/140 [==============================] - 31s 225ms/step - loss: 4.2118e-06 - accuracy: 1.0000 - val_loss: 0.8649 - val_accuracy: 0.9286
# Epoch 99/100
# 140/140 [==============================] - 30s 216ms/step - loss: 4.9990e-05 - accuracy: 1.0000 - val_loss: 0.8899 - val_accuracy: 0.9321
# Epoch 100/100
# 140/140 [==============================] - 31s 225ms/step - loss: 4.2678e-05 - accuracy: 1.0000 - val_loss: 0.8244 - val_accuracy: 0.9321

# %% [markdown]
# # **5. TEST THE MODEL**

# %% [markdown]
# #### Load testing dataset:
#
# ### make sure to change the `img_size` to the correct image size of the model:
# *   For ALEXNET, it is 227 by 227
# *   For VGG16, it is 224 by 224
# *   For RESNET, it is 224 by 224

# %%
img_size = 224

# I will free up the RAM
train_images = []
train_labels = []

# Load and preprocess test data
test_images = []
test_labels = []

test_dir = file_path + '/Testing/'
class_labels = ["epidote",  "no epidote"]


# Function to resize images to img_size
def resize_image(image_path):
    img = load_img(image_path, target_size=(img_size, img_size))
    img_array = img_to_array(img) / 255.0
    return img_array


for class_name in class_labels:
    class_dir = os.path.join(test_dir, class_name)
    for image_name in os.listdir(class_dir):
        image_path = os.path.join(class_dir, image_name)
        test_images.append(resize_image(image_path))
        test_labels.append(class_name)

#print(test_labels)
test_images = np.array(test_images)
# Encode class names into numerical labels

label_encoder = LabelEncoder()
label_encoder.fit(class_labels)
test_labels_encoded = label_encoder.transform(test_labels)

# Convert numerical labels to one-hot encoded vectors
test_labels = to_categorical(test_labels_encoded, num_classes=len(class_labels))

print('shape of test data',np.shape(test_labels))
# Out:
# shape of test data (149, 2)

# %% [markdown]
# #### Testing and calculating the evalution metrics
# **Don't forget to change lines 2 and 3:**

# %%
from keras.models import load_model

model = str("resnet_model") #either alex_model, vgg_model, resnet_model
model_name = str("resnet") #change to alexnet, vgg, resnet

model = load_model(file_path + '/Models/' + model)

# Predict probabilities for test data
y_pred_prob = model.predict(test_images)
# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)
# Convert one-hot encoded test labels to class labels
y_true = np.argmax(test_labels, axis=-1)
# Out:
# 5/5 [==============================] - 10s 632ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support

# Calculate confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Normalize confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plot normalized confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Normalized Confusion Matrix')

# Save confusion matrix image
plt.savefig(file_path + '/CM_'+model_name+'.png')

# Calculate precision, recall, and F1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')

# Print overall precision, recall, and F1-score
print("Overall Precision:", precision)
print("Overall Recall:", recall)
print("Overall F1-Score:", f1_score)


from sklearn.metrics import precision_recall_fscore_support, classification_report

# Calculate precision, recall, and F1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')

# Print classification report
report = classification_report(y_true, y_pred, target_names=class_labels)
print("Classification Report:\n", report)

# Specify the file path
file_path_1 = file_path+ "/Metric_"+model_name+".txt"

# Save classification report to a text file along with precision, recall, and F1-score
with open(file_path_1, 'w') as f:
    f.write("Precision: {:.4f}\n".format(precision))
    f.write("Recall: {:.4f}\n".format(recall))
    f.write("F1-score: {:.4f}\n\n".format(f1_score))
    f.write("Classification Report:\n")
    f.write(report)
# Out:
# Overall Precision: 0.8898252706741221
# Overall Recall: 0.8859060402684564
# Overall F1-Score: 0.8859060402684564
# Classification Report:
#                precision    recall  f1-score   support
#
#      epidote       0.85      0.93      0.89        71
#   no epidote       0.93      0.85      0.89        78
#
#     accuracy                           0.89       149
#    macro avg       0.89      0.89      0.89       149
# weighted avg       0.89      0.89      0.89       149
