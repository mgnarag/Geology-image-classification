# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/Geology-image-classification/blob/main/Model_for_epidote.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello Ate Grass!
#
# This notebook is still a work in progress. Di ko pa naeexplain lahat ng mga lines. Pero, we can run na this.
#
#
# Sa Google Drive natin na `Geology (Ate Grass)`, may excel file na CNN scores. Bale you will run **models 1,2,3,7,8,9**. Ako naman sa 4,5,6,10,11,12. Isang run lang ang pwede per google colab account. May limit din ang Google Colab  sa pag gamit ng GPU. Usually, I use my other google colab accounts pag ubos na hehe. Pwede mo rin siya irun simultaneously for different accounts. May tatlo akong email so may tatlo akong accounts.

# %% [markdown]
# # **1.Installing packages and connecting the google drive**

# %%
import torch
import torchvision
import torchvision.transforms as transforms

import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical
import os
from sklearn.model_selection import train_test_split

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd

import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # **2. Preparing the GDrive folder**
#
# First, go to Google Drive first. Nashare ko na noon yung folder na `Geology (Ate Grass)`. Nasa may "shared with me" siya sa google drive. Drag the whole folder sa "My Drive" para magcreate ng shortcut.
#
# Next, going back here sa Google Colab notebook, change the file_path in line 4 of the code below, depending on where the folder `3 classes (polarized)` is stored. An easy way to locate it is clicking the folder icon on the left side of this Colab Notebook. Select `drive`, then `MyDrive`. Hover the mouse on the target directory of the folder. Click the 3 dots, select `copy path`.
#
# Although I think yung nakalagay na file_path dito ay yun na mismo hehe. Palitan lang natin for the unpolarized  `3 classes (unpolarized)`

# %%
from google.colab import drive
drive.mount("/content/drive")
# !ls drive/My\ Drive
file_path = "/content/drive/MyDrive/Geology (Ate Grass)/2 classes (PPL)"
# Out:
# Mounted at /content/drive
# '107.1 syllabus 1SAY1920 FINAL.gdoc'
# '1C-01 Narag et al (1).pdf'
# '1C-01 Narag et al.pdf'
# '1FA971504AC646559D05A8ED6341AFB3[1025340].png'
# '1H-04 Narag et al.pdf'
#  20220802_182749.heic
#  20220802_182831.heic
#  20220802_183259.heic
#  20220803_125819.heic
#  20220803_125842.heic
#  20220803_144229.heic
#  20220803_144422.heic
#  20220803_160724.heic
#  20220803_160751.heic
#  20220803_165240.heic
#  20220803_165318.heic
#  20220803_174701.heic
#  20220803_174706.heic
#  20220804_175217.heic
#  20220804_175443.heic
#  20220804_175616.heic
#  20220804_181917.heic
#  20220804_182007.heic
#  20220804_182117.heic
#  2S22-23_LE3-Regular-Set-A-FINAL-KEY.pdf
# '3 classes (polarized)CM_alexnet.png'
# '3 classes (polarized)CM_vgg.png'
# 'A4_Physics 71 TWHFU-3_gradesheet (1).pdf'
# 'A4_Physics 71 TWHFU-3_officialgrades (1).pdf'
# 'A4_Physics 71 TWHFU-3_officialgrades.gdoc'
# 'Abstract - NARAG, Mark Jeremy.pdf'
# 'Annex 1 (copy of Journal).pdf'
# 'Annex 2 (Proof of employments).pdf'
# 'App Physics 181 THY-FX-2_studentcontactlist.xlsx'
#  Architectural_designs
# 'Arki abstract.pdf'
# 'Arki full paper.pdf'
# '[ART] Example of Objectives - Activities - Exp Output OPTIKAL WBS version 2.gsheet'
#  autoencoder_fine_tuned_6
# 'autoencoder_fine_tuned_6 (1)'
#  autoencoder_fine_tuned_6_b
# 'Baumgartner screenshots'
# 'Binarizing architectural drawings'
#  classification_report_nonTL.xlsx
#  classification_report.xlsx
#  Classroom
# 'Colab Notebooks'
# 'Color Difference Specification 2016.pptx'
#  confusion_matrix_nonTL.png
#  confusion_matrix_nonTL.xlsx
#  CS284
#  CS_NIP_201819_S2_BS_AppliedPhysics_Narag_Mark_Jeremy.pdf
#  D54dUVpU8AIZzoD.jpeg
#  Data.tex
# 'Dormitory Stay Request MNarag.docx.pdf'
# '[DRAFT-ART] UP Intelligent Systems Center Research Grant Application - Preview.docx'
#  DrzPc0sUwAAyQHi.jpeg
#  DvO96koV4AAD6PP.jpeg
# 'DvO976tVAAEQ9ym (1).jpeg'
#  DvO976tVAAEQ9ym.jpeg
# 'Employment Survey.gdoc'
#  Fast-Dreambooth
# 'FBC-2_Banez (1).pdf'
#  FBC-2_Banez.pdf
#  FdUaD2nUcAAki1b.jpeg
# 'Figure 1.png'
# 'Figure 2.png'
# 'fingerprint (1).pb'
# 'fingerprint (2).pb'
# 'fingerprint (3).pb'
# 'fingerprint (4).pb'
# 'fingerprint (5).pb'
#  fingerprint.pb
# 'Form5a and Grades.zip'
#  Fringes.zip
#  FSR_120201_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120202_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120212_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120221_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
# 'Geology (Ate Grass)'
# 'Geology (Ate Grass) (1)'
# 'Getting started.pdf'
#  IMG_4258.HEIC
#  IMG_4259.HEIC
#  IMG_4260.HEIC
#  IMG_4261.HEIC
#  IMG_4262.HEIC
#  IMG_4263.HEIC
#  IMG_4288.HEIC
#  IMG_5634.JPG
#  IMG_6572.jpeg
#  IMG_6578.jpeg
# 'IMG_6587 (1).jpeg'
#  IMG_6587.jpeg
#  IPA-Form4.1-2021Rev072021-1.pdf
#  IPA-Form4.2-2021Rev072021.docx
#  IPA-Form4.3-2021Rev072021.pdf
# 'item sample.tex'
# 'item template.tex'
# 'Jas Jem utang.gsheet'
#  Jem_face
# 'JFR Reduced Fees for 1st Sem AY 20-21.zip'
# 'Lecture 22 - Torque.pptx'
# 'Lecture 23 - Dynamics of Rotation.pptx'
# 'Lecture 24 - Angular Momentum.pptx'
# 'Lecture 25 - Equilibrium and Center of Gravity.pptx'
# 'Lecture 26 - Density and Pressure in a Fluid.pptx'
# 'Lecture 27 - Buoyancy.pptx'
# 'LRM_20220804_195432 (1).dng'
#  LRM_20220804_195432.dng
#  LRM_20220804_195500.dng
#  LRM_20220804_195546.dng
#  LRM_20220805_113837.dng
#  LRM_20220805_142837.dng
#  LRM_20220805_143054.dng
#  LRM_20220805_143817.dng
# 'MALIPOL_CHAE ANN.pdf'
#  Metric_100dpi.csv
#  Metric_500.csv
# 'NARAG_MARKJEREMY (1).BC.pdf'
#  NARAG_MARKJEREMY.BC.pdf
#  NARAG_MARKJEREMY.CC.png
#  NARAG_MARKJEREMY.dcog.pdf
#  NARAG_MARKJEREMY.DC.pdf
#  NARAG_MARKJEREMY.FL.pdf
#  NARAG_MARKJEREMY.Form1.1.pdf
#  NARAG_MARKJEREMY.POS.pdf
#  NARAG_MARKJEREMY.SD.pdf
#  NARAG_MARKJEREMY.TCGTOR.pdf
# '[NARAG] Physics 242 Final Report.pdf'
# '[NARAG] Physics 242 PS 1.pdf'
# '[NARAG] Physics 242 PS 2.pdf'
# 'Narag SPP Cert.pdf'
#  NARAG_Travel-Report-Form-2019.pdf
# 'NIP COVID-19 Case Report Form.gform'
# 'NIP COVID-19 Case Report Form (Responses).gsheet'
# 'NIP COVID19 Report.gsheet'
# 'NIP Year End Party 2022'
#  NRAG_MARKJEREMY.OTRTCG.pdf
# 'Optics in Art and Art Analysis (1).pptx'
# 'Optics in Art and Art Analysis.pptx'
# 'OUR CErtificate.gdoc'
# 'OUR CErtificate.pdf'
# 'output v1_100dpi.png'
# 'output v2_100dpi.png'
# 'output v3_100dpi.png'
# 'output v3_500.png'
# 'output v4_100dpi.png'
# 'output v5_100dpi.png'
# 'output v6_100dpi.png'
# 'OVCRD IPA Reference Slip (2021-0929-1691-5873).pdf'
# 'PA-08 Narag et al.pdf'
#  PA-08.pdf
# 'Parallel Presentation.gslides'
# 'PEER EVALUTION - Physics 72.1 HBC-1 .gform'
# 'PEER EVALUTION - Physics 72.1 TDE-1 .gform'
# 'PEER EVALUTION - Physics 72.1 WDE-1 .gform'
# 'PhD Candidacy Slides.pdf'
# 'PhD Candidacy Slides.pptx'
# 'Physics 107.1 Drive'
# 'Physics 107.1 MBCD-2_studentcontactlist.xlsx'
#  Physics305_plasma
# 'Physics 71.1 WIJ FIJ and 72.1 TBC.gsheet'
#  Physics_71_Syllabus.zip
# 'Physics_71_Syllabus.zip (Unzipped Files)'
# '[Physics 71 V-2] Attendance.gsheet'
# 'Physics 72.1 2nd Sem AY 2019-2020.gsheet'
# 'Rene Jem utang.gsheet'
# 'Research files'
# 'Sablay picture.jpeg'
# 'saved_model (1).pb'
# 'saved_model (2).pb'
# 'saved_model (3).pb'
# 'saved_model (4).pb'
# 'saved_model (5).pb'
#  saved_model.pb
# 'Screenshot 2023-02-12 at 12.13.51 (1).png'
# 'Screenshot 2023-02-12 at 12.13.51.png'
# 'Screenshot 2023-06-29 at 19.20.04.png'
# 'Screenshot 2023-06-29 at 19.26.09.png'
#  sd
#  Smokers.mp4
# 'SORRY SIR HUHU.gdoc'
# 'SORRY SIR HUHU.pdf'
# 'SPP-2023-1H-04 (1).pptx'
#  SPP-2023-1H-04.pptx
#  SPP_2023-Contributed-26.pdf
# 'SPP-2023-PB-05  .pdf'
#  SPP_Appearance-45.pdf
# 'SPP Cert of Appearance NARAG (1).pdf'
# 'SPP Cert of Appearance NARAG (2).pdf'
# 'SPP Cert of Appearance NARAG.pdf'
# 'Testing on DIV2K dataset.pdf'
# '[THY-FX] Physics 181 LE1 Submissions 2nd Sem AY 2020-21'
#  Travel-Report-Form-2019.pdf
# 'Undergraduate Research'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
# '[Updated] Physics 71 THQ-FQ-1_studentcontactlist (1).xlsx'
# '[Updated] Physics 71 THQ-FQ-1_studentcontactlist.xlsx'
# 'variables (1).data-00000-of-00001'
# 'variables (2).data-00000-of-00001'
# 'variables (3).data-00000-of-00001'
# 'variables (4).data-00000-of-00001'
# 'variables (5).data-00000-of-00001'
#  variables.data-00000-of-00001
# 'Waiver for more than 18 units [2nd sem AY 20-21].gdoc'

# %% [markdown]
# # **3.Preparing the training and validation dataset**
# ### make sure to change the `img_size` to the correct image size of the model:
# *   For ALEXNET, it is 227 by 227
# *   For VGG16, it is 224 by 224
# *   For RESNET, it is 224 by 224

# %%
img_size = 227

# Function to resize images to img_size
def resize_image(image_path):
    img = load_img(image_path, target_size=(img_size, img_size))
    img_array = img_to_array(img) / 255.0
    return img_array


def rot_and_flip(img):
  x = np.rot90(img, k=-1) #90
  train_images.append(x)
  train_labels.append(class_name)
  #train_images.append(np.fliplr(x))
  #train_labels.append(class_name)
  return x

# Load and preprocess training data
train_images = []
train_labels = []

train_dir = file_path + '/Training/'
class_labels = ["epidote",  "no epidote"]

for class_name in class_labels:
    class_dir = os.path.join(train_dir, class_name)
    for image_name in os.listdir(class_dir):
        image_path = os.path.join(class_dir, image_name)
        x = resize_image(image_path)
        train_images.append(x)
        train_labels.append(class_name)
        #rotate and flip if we want to augment. Pero wag muna
        #x = rot_and_flip(x) #90
        #x = rot_and_flip(x) #180
        #x = rot_and_flip(x) #270


# Convert lists to numpy arrays
train_images = np.array(train_images)
train_labels = np.array(train_labels)

print('shape of total dataset', np.shape(train_images))
print('shape of total dataset label', np.shape(train_labels))

# Encode class names into numerical labels
label_encoder = LabelEncoder()
label_encoder.fit(class_labels)
train_labels_encoded = label_encoder.fit_transform(train_labels)

# Convert numerical labels to one-hot encoded vectors
train_labels = to_categorical(train_labels_encoded, num_classes=len(class_labels))


#train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2, stratify=train_labels, random_state=42)

print('shape of dataset for training', np.shape(train_images))
print('shape of dataset label for training', np.shape(train_labels))
print('shape of dataset for validation', np.shape(val_images))
print('shape of dataset label for validation', np.shape(val_labels))
# Out:
# shape of total dataset (1400, 227, 227, 3)
# shape of total dataset label (1400,)
# shape of dataset for training (1120, 227, 227, 3)
# shape of dataset label for training (1120, 2)
# shape of dataset for validation (280, 227, 227, 3)
# shape of dataset label for validation (280, 2)

# %% [markdown]
#  Visualize:

# %%
import matplotlib.pyplot as plt

def display_images(images, labels, class_names, num_images=20):
    plt.figure(figsize=(15, 6))
    for i in range(num_images):
        plt.subplot(4, 5, i+1)
        plt.imshow(images[i])
        label_index = np.argmax(labels[i])
        plt.title(class_names[label_index])
        plt.axis('off')
    plt.show()

# Decode one-hot encoded labels back to class names
class_names = label_encoder.classes_

# Display the first 20 training images
display_images(train_images[:20], train_labels[:20], class_names)

# %% [markdown]
# # **4. Training the model**
#
# We will train three (3) different models. We will run them separately.

# %% [markdown]
# ### **RUN THIS FOR ALEXNET**
# There is no built-in model for alexnet so we have to create it from scratch

# %%
#AlexNet architecture from scratch
alex_model = Sequential([
    Conv2D(96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(227, 227, 3)),
    MaxPooling2D(pool_size=(3,3), strides=(2,2)),
    Conv2D(256, kernel_size=(5,5), activation='relu'),
    MaxPooling2D(pool_size=(3,3), strides=(2,2)),
    Conv2D(384, kernel_size=(3,3), activation='relu'),
    Conv2D(384, kernel_size=(3,3), activation='relu'),
    Conv2D(256, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(3,3), strides=(2,2)),
    Flatten(),
    Dense(4096, activation='relu'),
    Dropout(0.5),
    Dense(4096, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')
])


from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.0001)

alex_model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
# Train  model
alex_model.fit(train_images, train_labels, epochs=100, batch_size=8, validation_data=(val_images, val_labels))
alex_model.save(file_path + "/Models/alex_model")
# Out:
# Epoch 1/100
#  23/140 [===>..........................] - ETA: 2:50 - loss: 0.7099 - accuracy: 0.4783

# %% [markdown]
# ### **RUN THIS FOR VGG16**
# There is already a built-in model for vgg16 so we don't need to create it from scratch

# %%
# Load VGG16 mode:
vgg_base = tf.keras.applications.VGG16(include_top=False, input_shape=(224, 224, 3))
#Add "weights='imagenet'" if we want pretrained weights

# Freeze the pre-trained layers
for layer in vgg_base.layers:
    layer.trainable = True

# Add custom classifier layers on top of the pre-trained layers
x = Flatten()(vgg_base.output)
x = Dense(4096, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(4096, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(2, activation='softmax')(x) #because we have 3 classes

# Create the full model
vgg_model = Model(inputs=vgg_base.input, outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.00001)
vgg_model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
vgg_model.fit(train_images, train_labels, epochs=100, batch_size=8, validation_data=(val_images, val_labels))
vgg_model.save(file_path + "/Models/vgg_model")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Epoch 1/100
# 140/140 [==============================] - 39s 174ms/step - loss: 0.5651 - accuracy: 0.7196 - val_loss: 0.2652 - val_accuracy: 0.8857
# Epoch 2/100
# 140/140 [==============================] - 24s 173ms/step - loss: 0.2325 - accuracy: 0.9089 - val_loss: 0.1520 - val_accuracy: 0.9357
# Epoch 3/100
# 140/140 [==============================] - 25s 182ms/step - loss: 0.0785 - accuracy: 0.9723 - val_loss: 0.0556 - val_accuracy: 0.9750
# Epoch 4/100
# 140/140 [==============================] - 26s 184ms/step - loss: 0.0407 - accuracy: 0.9875 - val_loss: 0.1445 - val_accuracy: 0.9536
# Epoch 5/100
# 140/140 [==============================] - 26s 186ms/step - loss: 0.0489 - accuracy: 0.9866 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 6/100
# 140/140 [==============================] - 26s 188ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.0169 - val_accuracy: 0.9929
# Epoch 7/100
# 140/140 [==============================] - 26s 183ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 8/100
# 140/140 [==============================] - 27s 191ms/step - loss: 0.0438 - accuracy: 0.9857 - val_loss: 0.0305 - val_accuracy: 0.9857
# Epoch 9/100
# 140/140 [==============================] - 26s 186ms/step - loss: 0.0320 - accuracy: 0.9929 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 10/100
# 140/140 [==============================] - 26s 187ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 11/100
# 140/140 [==============================] - 26s 187ms/step - loss: 5.5386e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 12/100
# 140/140 [==============================] - 26s 188ms/step - loss: 9.3199e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 13/100
# 140/140 [==============================] - 26s 189ms/step - loss: 2.6342e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 14/100
# 140/140 [==============================] - 26s 189ms/step - loss: 1.8758e-04 - accuracy: 1.0000 - val_loss: 7.5774e-04 - val_accuracy: 1.0000
# Epoch 15/100
# 140/140 [==============================] - 27s 195ms/step - loss: 0.1633 - accuracy: 0.9580 - val_loss: 0.0301 - val_accuracy: 0.9857
# Epoch 16/100
# 140/140 [==============================] - 26s 189ms/step - loss: 0.0197 - accuracy: 0.9929 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 17/100
# 140/140 [==============================] - 27s 190ms/step - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.0106 - val_accuracy: 0.9964
# Epoch 18/100
# 140/140 [==============================] - 27s 190ms/step - loss: 0.0037 - accuracy: 0.9982 - val_loss: 0.0224 - val_accuracy: 0.9929
# Epoch 19/100
# 140/140 [==============================] - 27s 196ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 0.9964
# Epoch 20/100
# 140/140 [==============================] - 27s 196ms/step - loss: 4.5294e-04 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9964
# Epoch 21/100
# 140/140 [==============================] - 28s 199ms/step - loss: 1.0014e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 22/100
# 140/140 [==============================] - 27s 195ms/step - loss: 3.4959e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 23/100
# 140/140 [==============================] - 27s 190ms/step - loss: 4.0518e-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 24/100
# 140/140 [==============================] - 27s 196ms/step - loss: 1.2875e-04 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 25/100
# 140/140 [==============================] - 27s 190ms/step - loss: 1.8879e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 26/100
# 140/140 [==============================] - 27s 190ms/step - loss: 3.0531e-05 - accuracy: 1.0000 - val_loss: 9.9494e-04 - val_accuracy: 1.0000
# Epoch 27/100
# 140/140 [==============================] - 27s 190ms/step - loss: 4.1745e-05 - accuracy: 1.0000 - val_loss: 9.8180e-04 - val_accuracy: 1.0000
# Epoch 28/100
# 140/140 [==============================] - 27s 190ms/step - loss: 1.8208e-05 - accuracy: 1.0000 - val_loss: 8.4769e-04 - val_accuracy: 1.0000
# Epoch 29/100
# 140/140 [==============================] - 27s 190ms/step - loss: 1.2020e-05 - accuracy: 1.0000 - val_loss: 7.9658e-04 - val_accuracy: 1.0000
# Epoch 30/100
# 140/140 [==============================] - 27s 195ms/step - loss: 1.0856e-05 - accuracy: 1.0000 - val_loss: 7.5048e-04 - val_accuracy: 1.0000
# Epoch 31/100
# 140/140 [==============================] - 27s 195ms/step - loss: 2.1613e-05 - accuracy: 1.0000 - val_loss: 6.6722e-04 - val_accuracy: 1.0000
# Epoch 32/100
# 140/140 [==============================] - 27s 190ms/step - loss: 1.2704e-05 - accuracy: 1.0000 - val_loss: 6.2554e-04 - val_accuracy: 1.0000
# Epoch 33/100
# 140/140 [==============================] - 27s 195ms/step - loss: 3.3016e-05 - accuracy: 1.0000 - val_loss: 9.5844e-04 - val_accuracy: 1.0000
# Epoch 34/100
# 140/140 [==============================] - 27s 195ms/step - loss: 8.7581e-06 - accuracy: 1.0000 - val_loss: 8.5945e-04 - val_accuracy: 1.0000
# Epoch 35/100
# 140/140 [==============================] - 27s 190ms/step - loss: 8.1981e-06 - accuracy: 1.0000 - val_loss: 7.2060e-04 - val_accuracy: 1.0000
# Epoch 36/100
# 140/140 [==============================] - 27s 196ms/step - loss: 7.4039e-06 - accuracy: 1.0000 - val_loss: 6.7903e-04 - val_accuracy: 1.0000
# Epoch 37/100
# 140/140 [==============================] - 27s 190ms/step - loss: 5.8339e-06 - accuracy: 1.0000 - val_loss: 6.6644e-04 - val_accuracy: 1.0000
# Epoch 38/100
# 140/140 [==============================] - 27s 196ms/step - loss: 1.4109e-05 - accuracy: 1.0000 - val_loss: 4.9908e-04 - val_accuracy: 1.0000
# Epoch 39/100
# 140/140 [==============================] - 27s 190ms/step - loss: 1.5387e-05 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 40/100
# 140/140 [==============================] - 27s 196ms/step - loss: 9.6633e-06 - accuracy: 1.0000 - val_loss: 7.2562e-04 - val_accuracy: 1.0000
# Epoch 41/100
# 140/140 [==============================] - 27s 196ms/step - loss: 3.9430e-06 - accuracy: 1.0000 - val_loss: 7.2144e-04 - val_accuracy: 1.0000
# Epoch 42/100
# 140/140 [==============================] - 27s 190ms/step - loss: 1.1223e-05 - accuracy: 1.0000 - val_loss: 8.3796e-04 - val_accuracy: 1.0000
# Epoch 43/100
# 140/140 [==============================] - 27s 190ms/step - loss: 1.1102e-05 - accuracy: 1.0000 - val_loss: 9.2348e-04 - val_accuracy: 1.0000
# Epoch 44/100
# 140/140 [==============================] - 27s 190ms/step - loss: 3.0245e-05 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 45/100
# 140/140 [==============================] - 27s 195ms/step - loss: 5.4349e-06 - accuracy: 1.0000 - val_loss: 9.3637e-04 - val_accuracy: 1.0000
# Epoch 46/100
# 140/140 [==============================] - 27s 195ms/step - loss: 3.2923e-06 - accuracy: 1.0000 - val_loss: 7.6495e-04 - val_accuracy: 1.0000
# Epoch 47/100
# 140/140 [==============================] - 27s 196ms/step - loss: 3.1724e-06 - accuracy: 1.0000 - val_loss: 6.2094e-04 - val_accuracy: 1.0000
# Epoch 48/100
# 140/140 [==============================] - 27s 190ms/step - loss: 1.7384e-06 - accuracy: 1.0000 - val_loss: 5.5125e-04 - val_accuracy: 1.0000
# Epoch 49/100
# 140/140 [==============================] - 27s 190ms/step - loss: 2.7113e-06 - accuracy: 1.0000 - val_loss: 6.3096e-04 - val_accuracy: 1.0000
# Epoch 50/100
# 140/140 [==============================] - 27s 190ms/step - loss: 2.0569e-06 - accuracy: 1.0000 - val_loss: 5.3690e-04 - val_accuracy: 1.0000
# Epoch 51/100
# 140/140 [==============================] - 27s 196ms/step - loss: 8.9125e-06 - accuracy: 1.0000 - val_loss: 7.6343e-04 - val_accuracy: 1.0000
# Epoch 52/100
# 140/140 [==============================] - 27s 190ms/step - loss: 1.5208e-06 - accuracy: 1.0000 - val_loss: 3.8270e-04 - val_accuracy: 1.0000
# Epoch 53/100
# 140/140 [==============================] - 27s 196ms/step - loss: 6.4816e-06 - accuracy: 1.0000 - val_loss: 6.9926e-04 - val_accuracy: 1.0000
# Epoch 54/100
# 140/140 [==============================] - 27s 190ms/step - loss: 2.4404e-06 - accuracy: 1.0000 - val_loss: 7.5596e-04 - val_accuracy: 1.0000
# Epoch 55/100
# 140/140 [==============================] - 27s 191ms/step - loss: 1.0268e-06 - accuracy: 1.0000 - val_loss: 5.4832e-04 - val_accuracy: 1.0000
# Epoch 56/100
# 140/140 [==============================] - 27s 190ms/step - loss: 1.0945e-06 - accuracy: 1.0000 - val_loss: 5.2894e-04 - val_accuracy: 1.0000
# Epoch 57/100
# 140/140 [==============================] - 27s 190ms/step - loss: 6.8969e-07 - accuracy: 1.0000 - val_loss: 5.3111e-04 - val_accuracy: 1.0000
# Epoch 58/100
# 140/140 [==============================] - 27s 196ms/step - loss: 1.1396e-06 - accuracy: 1.0000 - val_loss: 4.9292e-04 - val_accuracy: 1.0000
# Epoch 59/100
# 140/140 [==============================] - 27s 190ms/step - loss: 7.0747e-07 - accuracy: 1.0000 - val_loss: 4.9246e-04 - val_accuracy: 1.0000
# Epoch 60/100
# 140/140 [==============================] - 27s 190ms/step - loss: 1.4529e-06 - accuracy: 1.0000 - val_loss: 4.9515e-04 - val_accuracy: 1.0000
# Epoch 61/100
# 140/140 [==============================] - 27s 190ms/step - loss: 2.3135e-06 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 62/100
# 140/140 [==============================] - 27s 195ms/step - loss: 1.8912e-06 - accuracy: 1.0000 - val_loss: 5.7146e-04 - val_accuracy: 1.0000
# Epoch 63/100
# 140/140 [==============================] - 27s 190ms/step - loss: 8.0826e-07 - accuracy: 1.0000 - val_loss: 5.5344e-04 - val_accuracy: 1.0000
# Epoch 64/100
# 140/140 [==============================] - 27s 190ms/step - loss: 5.0535e-07 - accuracy: 1.0000 - val_loss: 5.4739e-04 - val_accuracy: 1.0000
# Epoch 65/100
# 140/140 [==============================] - 27s 195ms/step - loss: 1.2045e-06 - accuracy: 1.0000 - val_loss: 6.4064e-04 - val_accuracy: 1.0000
# Epoch 66/100
# 140/140 [==============================] - 27s 195ms/step - loss: 4.2308e-07 - accuracy: 1.0000 - val_loss: 7.0949e-04 - val_accuracy: 1.0000
# Epoch 67/100
# 140/140 [==============================] - 27s 195ms/step - loss: 1.0528e-06 - accuracy: 1.0000 - val_loss: 6.5715e-04 - val_accuracy: 1.0000
# Epoch 68/100
# 140/140 [==============================] - 27s 195ms/step - loss: 2.2523e-06 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9964
# Epoch 69/100
# 140/140 [==============================] - 27s 190ms/step - loss: 9.0038e-07 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 70/100
# 140/140 [==============================] - 27s 190ms/step - loss: 3.4463e-07 - accuracy: 1.0000 - val_loss: 8.5694e-04 - val_accuracy: 1.0000
# Epoch 71/100
# 140/140 [==============================] - 27s 190ms/step - loss: 3.8253e-07 - accuracy: 1.0000 - val_loss: 7.3802e-04 - val_accuracy: 1.0000
# Epoch 72/100
# 140/140 [==============================] - 27s 196ms/step - loss: 1.3384e-06 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 73/100
# 140/140 [==============================] - 27s 190ms/step - loss: 3.1600e-07 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 74/100
# 140/140 [==============================] - 27s 195ms/step - loss: 1.9695e-06 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 75/100
# 140/140 [==============================] - 27s 195ms/step - loss: 4.2221e-07 - accuracy: 1.0000 - val_loss: 4.5577e-04 - val_accuracy: 1.0000
# Epoch 76/100
# 140/140 [==============================] - 27s 190ms/step - loss: 2.3044e-06 - accuracy: 1.0000 - val_loss: 3.6110e-04 - val_accuracy: 1.0000
# Epoch 77/100
# 140/140 [==============================] - 27s 190ms/step - loss: 2.0893e-07 - accuracy: 1.0000 - val_loss: 3.6376e-04 - val_accuracy: 1.0000
# Epoch 78/100
# 140/140 [==============================] - 27s 190ms/step - loss: 2.5417e-07 - accuracy: 1.0000 - val_loss: 3.4368e-04 - val_accuracy: 1.0000
# Epoch 79/100
# 140/140 [==============================] - 27s 196ms/step - loss: 3.8504e-07 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 80/100
# 140/140 [==============================] - 27s 190ms/step - loss: 8.6959e-08 - accuracy: 1.0000 - val_loss: 9.6363e-04 - val_accuracy: 1.0000
# Epoch 81/100
# 140/140 [==============================] - 27s 191ms/step - loss: 2.6662e-07 - accuracy: 1.0000 - val_loss: 5.0738e-04 - val_accuracy: 1.0000
# Epoch 82/100
# 140/140 [==============================] - 27s 190ms/step - loss: 1.6093e-07 - accuracy: 1.0000 - val_loss: 3.9579e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 140/140 [==============================] - 27s 190ms/step - loss: 4.7258e-08 - accuracy: 1.0000 - val_loss: 3.9378e-04 - val_accuracy: 1.0000
# Epoch 84/100
# 140/140 [==============================] - 27s 195ms/step - loss: 1.1027e-07 - accuracy: 1.0000 - val_loss: 3.8289e-04 - val_accuracy: 1.0000
# Epoch 85/100
# 140/140 [==============================] - 27s 190ms/step - loss: 7.5995e-08 - accuracy: 1.0000 - val_loss: 3.9670e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 140/140 [==============================] - 27s 190ms/step - loss: 7.9721e-08 - accuracy: 1.0000 - val_loss: 3.9646e-04 - val_accuracy: 1.0000
# Epoch 87/100
# 140/140 [==============================] - 27s 196ms/step - loss: 8.2382e-08 - accuracy: 1.0000 - val_loss: 4.0491e-04 - val_accuracy: 1.0000
# Epoch 88/100
# 140/140 [==============================] - 27s 196ms/step - loss: 6.5778e-08 - accuracy: 1.0000 - val_loss: 3.3907e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 140/140 [==============================] - 27s 196ms/step - loss: 1.5337e-07 - accuracy: 1.0000 - val_loss: 2.5603e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 140/140 [==============================] - 27s 190ms/step - loss: 5.9179e-08 - accuracy: 1.0000 - val_loss: 2.3975e-04 - val_accuracy: 1.0000
# Epoch 91/100
# 140/140 [==============================] - 27s 196ms/step - loss: 5.2362e-07 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 92/100
# 140/140 [==============================] - 27s 196ms/step - loss: 2.9342e-07 - accuracy: 1.0000 - val_loss: 3.7790e-04 - val_accuracy: 1.0000
# Epoch 93/100
# 140/140 [==============================] - 27s 191ms/step - loss: 8.0997e-08 - accuracy: 1.0000 - val_loss: 2.8064e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 140/140 [==============================] - 27s 190ms/step - loss: 4.4384e-08 - accuracy: 1.0000 - val_loss: 3.0192e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 140/140 [==============================] - 27s 191ms/step - loss: 1.7988e-08 - accuracy: 1.0000 - val_loss: 3.1071e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 140/140 [==============================] - 27s 190ms/step - loss: 3.5656e-08 - accuracy: 1.0000 - val_loss: 3.6548e-04 - val_accuracy: 1.0000
# Epoch 97/100
# 140/140 [==============================] - 27s 190ms/step - loss: 4.6193e-08 - accuracy: 1.0000 - val_loss: 4.9959e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 140/140 [==============================] - 27s 191ms/step - loss: 2.7035e-08 - accuracy: 1.0000 - val_loss: 5.6007e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 140/140 [==============================] - 27s 196ms/step - loss: 3.7040e-08 - accuracy: 1.0000 - val_loss: 5.2872e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 140/140 [==============================] - 27s 190ms/step - loss: 9.4940e-08 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000

# %% [markdown]
# ### **RUN THIS FOR RESNET**

# %%
resnet_base = tf.keras.applications.ResNet50(include_top=False, input_shape=(224, 224, 3))

# Freeze the pre-trained layers
for layer in resnet_base.layers:
    layer.trainable = True

# Add custom classifier layers on top of the pre-trained layers
x = Flatten()(resnet_base.output)
x = Dense(4096, activation='relu')(x)
x = Dense(4096, activation='relu')(x)
output = Dense(2, activation='softmax')(x)

# Create the full model
resnet_model = Model(inputs=resnet_base.input, outputs=output)

# Compile the model
optimizer = Adam(learning_rate=0.00001)
resnet_model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
resnet_model.fit(train_images, train_labels, epochs=100, batch_size=8, validation_data=(val_images, val_labels))
resnet_model.save(file_path + "/Models/resnet_model")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Epoch 1/100
# 140/140 [==============================] - 75s 225ms/step - loss: 0.4399 - accuracy: 0.8589 - val_loss: 1.3979 - val_accuracy: 0.5000
# Epoch 2/100
# 140/140 [==============================] - 31s 225ms/step - loss: 0.0414 - accuracy: 0.9857 - val_loss: 1.1250 - val_accuracy: 0.5036
# Epoch 3/100
# 140/140 [==============================] - 30s 217ms/step - loss: 0.0108 - accuracy: 0.9973 - val_loss: 1.5816 - val_accuracy: 0.5000
# Epoch 4/100
# 140/140 [==============================] - 32s 228ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 1.6521 - val_accuracy: 0.5000
# Epoch 5/100
# 140/140 [==============================] - 31s 220ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.9346 - val_accuracy: 0.5036
# Epoch 6/100
# 140/140 [==============================] - 31s 220ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.3939 - val_accuracy: 0.5536
# Epoch 7/100
# 140/140 [==============================] - 31s 220ms/step - loss: 0.0757 - accuracy: 0.9768 - val_loss: 2.6068 - val_accuracy: 0.6607
# Epoch 8/100
# 140/140 [==============================] - 32s 229ms/step - loss: 0.0824 - accuracy: 0.9812 - val_loss: 0.2889 - val_accuracy: 0.9214
# Epoch 9/100
# 140/140 [==============================] - 31s 222ms/step - loss: 0.0053 - accuracy: 0.9964 - val_loss: 1.0040 - val_accuracy: 0.8607
# Epoch 10/100
# 140/140 [==============================] - 31s 221ms/step - loss: 0.0476 - accuracy: 0.9866 - val_loss: 0.1066 - val_accuracy: 0.9786
# Epoch 11/100
# 140/140 [==============================] - 31s 222ms/step - loss: 0.0254 - accuracy: 0.9982 - val_loss: 0.3529 - val_accuracy: 0.9464
# Epoch 12/100
# 140/140 [==============================] - 31s 222ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.1503 - val_accuracy: 0.9750
# Epoch 13/100
# 140/140 [==============================] - 31s 223ms/step - loss: 0.0104 - accuracy: 0.9946 - val_loss: 0.0541 - val_accuracy: 0.9857
# Epoch 14/100
# 140/140 [==============================] - 32s 232ms/step - loss: 0.0016 - accuracy: 0.9991 - val_loss: 0.0692 - val_accuracy: 0.9857
# Epoch 15/100
# 140/140 [==============================] - 31s 222ms/step - loss: 0.0647 - accuracy: 0.9875 - val_loss: 0.0926 - val_accuracy: 0.9714
# Epoch 16/100
# 140/140 [==============================] - 32s 231ms/step - loss: 0.0534 - accuracy: 0.9893 - val_loss: 0.2136 - val_accuracy: 0.9821
# Epoch 17/100
# 140/140 [==============================] - 32s 231ms/step - loss: 0.0016 - accuracy: 0.9991 - val_loss: 0.0432 - val_accuracy: 0.9893
# Epoch 18/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0215 - accuracy: 0.9964 - val_loss: 0.0958 - val_accuracy: 0.9714
# Epoch 19/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0416 - accuracy: 0.9920 - val_loss: 0.0171 - val_accuracy: 0.9893
# Epoch 20/100
# 140/140 [==============================] - 32s 231ms/step - loss: 0.0012 - accuracy: 0.9991 - val_loss: 0.0182 - val_accuracy: 0.9929
# Epoch 21/100
# 140/140 [==============================] - 32s 232ms/step - loss: 2.8788e-05 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9929
# Epoch 22/100
# 140/140 [==============================] - 32s 231ms/step - loss: 0.0098 - accuracy: 0.9991 - val_loss: 0.0709 - val_accuracy: 0.9929
# Epoch 23/100
# 140/140 [==============================] - 32s 232ms/step - loss: 0.0136 - accuracy: 0.9973 - val_loss: 0.1847 - val_accuracy: 0.9750
# Epoch 24/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0147 - accuracy: 0.9964 - val_loss: 0.0192 - val_accuracy: 0.9929
# Epoch 25/100
# 140/140 [==============================] - 31s 223ms/step - loss: 2.0772e-04 - accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 0.9893
# Epoch 26/100
# 140/140 [==============================] - 31s 224ms/step - loss: 9.7498e-04 - accuracy: 0.9991 - val_loss: 0.1709 - val_accuracy: 0.9643
# Epoch 27/100
# 140/140 [==============================] - 31s 223ms/step - loss: 0.0306 - accuracy: 0.9946 - val_loss: 0.0913 - val_accuracy: 0.9857
# Epoch 28/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0195 - accuracy: 0.9964 - val_loss: 0.5037 - val_accuracy: 0.9714
# Epoch 29/100
# 140/140 [==============================] - 32s 232ms/step - loss: 0.0337 - accuracy: 0.9946 - val_loss: 0.0893 - val_accuracy: 0.9821
# Epoch 30/100
# 140/140 [==============================] - 31s 223ms/step - loss: 0.0181 - accuracy: 0.9973 - val_loss: 0.1310 - val_accuracy: 0.9821
# Epoch 31/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.0440 - val_accuracy: 0.9929
# Epoch 32/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0070 - accuracy: 0.9982 - val_loss: 0.0940 - val_accuracy: 0.9857
# Epoch 33/100
# 140/140 [==============================] - 32s 232ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.2360 - val_accuracy: 0.9643
# Epoch 34/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0014 - accuracy: 0.9991 - val_loss: 0.1460 - val_accuracy: 0.9857
# Epoch 35/100
# 140/140 [==============================] - 32s 232ms/step - loss: 6.4436e-07 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9857
# Epoch 36/100
# 140/140 [==============================] - 31s 225ms/step - loss: 0.0025 - accuracy: 0.9982 - val_loss: 0.2535 - val_accuracy: 0.9821
# Epoch 37/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0166 - accuracy: 0.9982 - val_loss: 0.0289 - val_accuracy: 0.9929
# Epoch 38/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0360 - accuracy: 0.9982 - val_loss: 0.0817 - val_accuracy: 0.9893
# Epoch 39/100
# 140/140 [==============================] - 32s 232ms/step - loss: 1.1165e-05 - accuracy: 1.0000 - val_loss: 0.0795 - val_accuracy: 0.9893
# Epoch 40/100
# 140/140 [==============================] - 32s 232ms/step - loss: 2.1829e-05 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.9929
# Epoch 41/100
# 140/140 [==============================] - 32s 232ms/step - loss: 9.3853e-06 - accuracy: 1.0000 - val_loss: 0.0815 - val_accuracy: 0.9929
# Epoch 42/100
# 140/140 [==============================] - 31s 224ms/step - loss: 2.8873e-07 - accuracy: 1.0000 - val_loss: 0.0841 - val_accuracy: 0.9929
# Epoch 43/100
# 140/140 [==============================] - 32s 232ms/step - loss: 3.8679e-06 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 0.9929
# Epoch 44/100
# 140/140 [==============================] - 32s 232ms/step - loss: 1.0122e-07 - accuracy: 1.0000 - val_loss: 0.0842 - val_accuracy: 0.9929
# Epoch 45/100
# 140/140 [==============================] - 31s 224ms/step - loss: 2.0372e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9821
# Epoch 46/100
# 140/140 [==============================] - 32s 232ms/step - loss: 3.5017e-08 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9857
# Epoch 47/100
# 140/140 [==============================] - 31s 224ms/step - loss: 4.5760e-06 - accuracy: 1.0000 - val_loss: 0.1062 - val_accuracy: 0.9857
# Epoch 48/100
# 140/140 [==============================] - 33s 233ms/step - loss: 7.6634e-09 - accuracy: 1.0000 - val_loss: 0.1078 - val_accuracy: 0.9857
# Epoch 49/100
# 140/140 [==============================] - 31s 223ms/step - loss: 1.3623e-07 - accuracy: 1.0000 - val_loss: 0.1049 - val_accuracy: 0.9857
# Epoch 50/100
# 140/140 [==============================] - 31s 224ms/step - loss: 2.2851e-07 - accuracy: 1.0000 - val_loss: 0.1048 - val_accuracy: 0.9857
# Epoch 51/100
# 140/140 [==============================] - 32s 232ms/step - loss: 4.5295e-07 - accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 0.9857
# Epoch 52/100
# 140/140 [==============================] - 32s 231ms/step - loss: 4.0339e-08 - accuracy: 1.0000 - val_loss: 0.1107 - val_accuracy: 0.9857
# Epoch 53/100
# 140/140 [==============================] - 31s 224ms/step - loss: 8.5138e-07 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9857
# Epoch 54/100
# 140/140 [==============================] - 32s 231ms/step - loss: 1.3910e-07 - accuracy: 1.0000 - val_loss: 0.1017 - val_accuracy: 0.9857
# Epoch 55/100
# 140/140 [==============================] - 32s 232ms/step - loss: 4.2716e-05 - accuracy: 1.0000 - val_loss: 0.2374 - val_accuracy: 0.9750
# Epoch 56/100
# 140/140 [==============================] - 32s 231ms/step - loss: 1.8087e-05 - accuracy: 1.0000 - val_loss: 0.1754 - val_accuracy: 0.9786
# Epoch 57/100
# 140/140 [==============================] - 32s 231ms/step - loss: 5.4555e-06 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9821
# Epoch 58/100
# 140/140 [==============================] - 32s 232ms/step - loss: 1.7204e-06 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9821
# Epoch 59/100
# 140/140 [==============================] - 32s 231ms/step - loss: 2.0870e-06 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9821
# Epoch 60/100
# 140/140 [==============================] - 31s 223ms/step - loss: 2.5611e-05 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9929
# Epoch 61/100
# 140/140 [==============================] - 32s 231ms/step - loss: 6.1650e-06 - accuracy: 1.0000 - val_loss: 0.0781 - val_accuracy: 0.9929
# Epoch 62/100
# 140/140 [==============================] - 32s 231ms/step - loss: 0.0322 - accuracy: 0.9955 - val_loss: 0.3363 - val_accuracy: 0.9786
# Epoch 63/100
# 140/140 [==============================] - 32s 231ms/step - loss: 0.1538 - accuracy: 0.9866 - val_loss: 0.0642 - val_accuracy: 0.9893
# Epoch 64/100
# 140/140 [==============================] - 31s 223ms/step - loss: 0.0310 - accuracy: 0.9964 - val_loss: 1.5461 - val_accuracy: 0.9250
# Epoch 65/100
# 140/140 [==============================] - 31s 224ms/step - loss: 0.0183 - accuracy: 0.9991 - val_loss: 0.1723 - val_accuracy: 0.9857
# Epoch 66/100
# 140/140 [==============================] - 32s 231ms/step - loss: 1.7636e-05 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.9857
# Epoch 67/100
# 140/140 [==============================] - 31s 223ms/step - loss: 0.0084 - accuracy: 0.9991 - val_loss: 0.0473 - val_accuracy: 0.9893
# Epoch 68/100
# 140/140 [==============================] - 32s 232ms/step - loss: 0.0094 - accuracy: 0.9964 - val_loss: 0.0395 - val_accuracy: 0.9893
# Epoch 69/100
# 140/140 [==============================] - 31s 223ms/step - loss: 0.1036 - accuracy: 0.9946 - val_loss: 0.0408 - val_accuracy: 0.9857
# Epoch 70/100
# 140/140 [==============================] - 32s 231ms/step - loss: 0.0098 - accuracy: 0.9982 - val_loss: 0.2275 - val_accuracy: 0.9643
# Epoch 71/100
# 140/140 [==============================] - 32s 231ms/step - loss: 0.0052 - accuracy: 0.9973 - val_loss: 0.0207 - val_accuracy: 0.9964
# Epoch 72/100
# 140/140 [==============================] - 32s 231ms/step - loss: 7.6401e-06 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9964
# Epoch 73/100
# 140/140 [==============================] - 32s 232ms/step - loss: 1.8775e-07 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9964
# Epoch 74/100
# 140/140 [==============================] - 32s 231ms/step - loss: 4.5636e-07 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9964
# Epoch 75/100
# 140/140 [==============================] - 31s 223ms/step - loss: 2.2265e-06 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9964
# Epoch 76/100
# 140/140 [==============================] - 31s 223ms/step - loss: 3.2857e-06 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9964
# Epoch 77/100
# 140/140 [==============================] - 32s 231ms/step - loss: 8.1211e-08 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9964
# Epoch 78/100
# 140/140 [==============================] - 32s 231ms/step - loss: 6.8497e-07 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9964
# Epoch 79/100
# 140/140 [==============================] - 31s 223ms/step - loss: 3.2018e-06 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9964
# Epoch 80/100
# 140/140 [==============================] - 32s 232ms/step - loss: 5.3644e-08 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 0.9964
# Epoch 81/100
# 140/140 [==============================] - 31s 223ms/step - loss: 1.0431e-08 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9964
# Epoch 82/100
# 140/140 [==============================] - 32s 232ms/step - loss: 1.0297e-06 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 0.9964
# Epoch 83/100
# 140/140 [==============================] - 31s 224ms/step - loss: 1.4212e-06 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9964
# Epoch 84/100
# 140/140 [==============================] - 31s 223ms/step - loss: 1.4117e-06 - accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 0.9964
# Epoch 85/100
# 140/140 [==============================] - 32s 232ms/step - loss: 1.3349e-05 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 0.9964
# Epoch 86/100
# 140/140 [==============================] - 31s 223ms/step - loss: 2.1169e-06 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9964
# Epoch 87/100
# 140/140 [==============================] - 31s 223ms/step - loss: 4.2989e-06 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9964
# Epoch 88/100
# 140/140 [==============================] - 31s 224ms/step - loss: 9.3450e-08 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 0.9964
# Epoch 89/100
# 140/140 [==============================] - 31s 223ms/step - loss: 1.1989e-06 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 0.9964
# Epoch 90/100
# 140/140 [==============================] - 32s 232ms/step - loss: 3.1718e-08 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 0.9964
# Epoch 91/100
# 140/140 [==============================] - 31s 223ms/step - loss: 5.8858e-08 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 0.9964
# Epoch 92/100
# 140/140 [==============================] - 32s 232ms/step - loss: 9.6318e-07 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9964
# Epoch 93/100
# 140/140 [==============================] - 31s 223ms/step - loss: 1.7136e-08 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 0.9964
# Epoch 94/100
# 140/140 [==============================] - 31s 223ms/step - loss: 8.7916e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9964
# Epoch 95/100
# 140/140 [==============================] - 31s 224ms/step - loss: 1.2985e-08 - accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 0.9964
# Epoch 96/100
# 140/140 [==============================] - 31s 223ms/step - loss: 1.1175e-07 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9964
# Epoch 97/100
# 140/140 [==============================] - 31s 223ms/step - loss: 3.2676e-08 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 0.9964
# Epoch 98/100
# 140/140 [==============================] - 32s 232ms/step - loss: 1.5965e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9964
# Epoch 99/100
# 140/140 [==============================] - 32s 231ms/step - loss: 1.2293e-07 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9964
# Epoch 100/100
# 140/140 [==============================] - 32s 231ms/step - loss: 2.1892e-07 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9964

# %% [markdown]
# # **5. TEST THE MODEL**

# %% [markdown]
# #### Load testing dataset:
#
# ### make sure to change the `img_size` to the correct image size of the model:
# *   For ALEXNET, it is 227 by 227
# *   For VGG16, it is 224 by 224
# *   For RESNET, it is 224 by 224

# %%
img_size = 227

# I will free up the RAM
train_images = []
train_labels = []

# Load and preprocess test data
test_images = []
test_labels = []

test_dir = file_path + '/Testing/'
class_labels = ["epidote",  "no epidote"]


# Function to resize images to img_size
def resize_image(image_path):
    img = load_img(image_path, target_size=(img_size, img_size))
    img_array = img_to_array(img) / 255.0
    return img_array


for class_name in class_labels:
    class_dir = os.path.join(test_dir, class_name)
    for image_name in os.listdir(class_dir):
        image_path = os.path.join(class_dir, image_name)
        test_images.append(resize_image(image_path))
        test_labels.append(class_name)

#print(test_labels)
test_images = np.array(test_images)
# Encode class names into numerical labels

label_encoder = LabelEncoder()
label_encoder.fit(class_labels)
test_labels_encoded = label_encoder.transform(test_labels)

# Convert numerical labels to one-hot encoded vectors
test_labels = to_categorical(test_labels_encoded, num_classes=len(class_labels))

print('shape of test data',np.shape(test_labels))

# %% [markdown]
# #### Testing and calculating the evalution metrics
# **Don't forget to change lines 2 and 3:**

# %%
from keras.models import load_model

model = str("alex_model") #either alex_model, vgg_model, resnet_model
model_name = str("alexnet") #change to alexnet, vgg, resnet

model = load_model(file_path + '/Models/' + model)

# Predict probabilities for test data
y_pred_prob = model.predict(test_images)
# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)
# Convert one-hot encoded test labels to class labels
y_true = np.argmax(test_labels, axis=-1)

# %%
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support

# Calculate confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Normalize confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plot normalized confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Normalized Confusion Matrix')

# Save confusion matrix image
plt.savefig(file_path + '/CM_'+model_name+'.png')

# Calculate precision, recall, and F1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')

# Print overall precision, recall, and F1-score
print("Overall Precision:", precision)
print("Overall Recall:", recall)
print("Overall F1-Score:", f1_score)


from sklearn.metrics import precision_recall_fscore_support, classification_report

# Calculate precision, recall, and F1-score
precision, recall, f1_score, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')

# Print classification report
report = classification_report(y_true, y_pred, target_names=class_labels)
print("Classification Report:\n", report)

# Specify the file path
file_path_1 = file_path+ "/Metric_"+model_name+".txt"

# Save classification report to a text file along with precision, recall, and F1-score
with open(file_path_1, 'w') as f:
    f.write("Precision: {:.4f}\n".format(precision))
    f.write("Recall: {:.4f}\n".format(recall))
    f.write("F1-score: {:.4f}\n\n".format(f1_score))
    f.write("Classification Report:\n")
    f.write(report)
